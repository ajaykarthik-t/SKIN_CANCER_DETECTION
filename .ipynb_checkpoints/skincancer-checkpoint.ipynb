# %%
import os
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
import random
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation, GlobalMaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
# Out:
# WARNING:tensorflow:From C:\Users\ajayk\anaconda3\envs\nus\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
pip install tensorflow-hub
# Out:
# Requirement already satisfied: tensorflow-hub in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-hub) (4.25.3)
# Requirement already satisfied: tf-keras>=2.14.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-hub) (2.16.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (23.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (3.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (0.41.2)
# Requirement already satisfied: rich in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (13.7.1)
# Requirement already satisfied: namex in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (0.0.7)
# Requirement already satisfied: optree in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (0.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow-hub) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (1.32.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (2.2.1)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (15.0.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (3.1.42)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from streamlit) (4.0.0)
# Requirement already satisfied: jinja2 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: colorama in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from requests<3,>=2.27->streamlit) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install split-folders
# Out:
# Requirement already satisfied: split-folders in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (0.5.1)

# %%
import splitfolders

# %%
splitfolders.ratio(r"C:/Users/ajayk/Desktop/skincancer/databse", output="output",
    seed=1337, ratio=(.75, .2, .05), group_prefix=None, move=False)

# %%
data_dir = pathlib.Path('output/')
train_dir = 'output/train'
val_dir = 'output/val'
test_dir = 'output/test'

# %%
class_name = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_name)
# Out:
# ['test' 'train' 'val']

# %%
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 3 folder and 0 images in output
# 3 folder and 0 images in output\test
# 0 folder and 4 images in output\test\Dermatofibroma
# 0 folder and 4 images in output\test\Melanocyticnevus
# 0 folder and 4 images in output\test\Melanoma
# 3 folder and 0 images in output\train
# 0 folder and 60 images in output\train\Dermatofibroma
# 0 folder and 60 images in output\train\Melanocyticnevus
# 0 folder and 60 images in output\train\Melanoma
# 3 folder and 0 images in output\val
# 0 folder and 16 images in output\val\Dermatofibroma
# 0 folder and 16 images in output\val\Melanocyticnevus
# 0 folder and 16 images in output\val\Melanoma

# %%
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    
    print(f"Image Shape : {img.shape}")
    plt.show()

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Melanocyticnevus')
# Out:
# Image Shape : (768, 1024, 3)

# %%
# Sets the global random seed.
tf.random.set_seed(46)

# preprocess data
train_datagen = ImageDataGenerator(rescale=1/255.0,
                                   rotation_range=0.2,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   vertical_flip=True,
                                   horizontal_flip=True)
valid_datagen = ImageDataGenerator(rescale=1/255.0)
test_datagen = ImageDataGenerator(rescale=1/255.0)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=True,
                                               seed=46)

valid_data = valid_datagen.flow_from_directory(val_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)

test_data = test_datagen.flow_from_directory(test_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)
# Out:
# Found 180 images belonging to 3 classes.
# Found 48 images belonging to 3 classes.
# Found 12 images belonging to 3 classes.

# %%
train_data.class_indices
# Out:
# {'Dermatofibroma': 0, 'Melanocyticnevus': 1, 'Melanoma': 2}

# %%
train_y=train_data.classes
val_y=valid_data.classes
test_y=test_data.classes

# %%
print("train_y.shape: ", train_y.shape)
print("val_y.shape: ", val_y.shape)
print("test_y.shape: ", test_y.shape)
# Out:
# train_y.shape:  (180,)
# val_y.shape:  (48,)
# test_y.shape:  (12,)

# %%
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3),
                                                        include_top=False,
                                                        weights='imagenet')
base_model.trainable = False

# %%
global_average_layer = GlobalAveragePooling2D()
prediction_layer = Dense(3)
softmax = Activation('softmax')

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = Dropout(0.25)(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
outputs = softmax(outputs)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │         3,075 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,040,579 (26.86 MB)
#  Trainable params: 3,075 (12.01 KB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# train model
history = model.fit(train_data, epochs=25, validation_data=valid_data)
# Out:
# Epoch 1/25
# C:\Users\ajayk\anaconda3\envs\nus\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 35s 8s/step - accuracy: 0.3952 - loss: 1.1777 - val_accuracy: 0.3750 - val_loss: 1.2099
# Epoch 2/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 0.4216 - loss: 1.1238 - val_accuracy: 0.4792 - val_loss: 1.1360
# Epoch 3/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.4927 - loss: 1.0331 - val_accuracy: 0.5000 - val_loss: 1.0577
# Epoch 4/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.5640 - loss: 0.9234 - val_accuracy: 0.5833 - val_loss: 0.9891
# Epoch 5/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.5684 - loss: 0.9485 - val_accuracy: 0.6042 - val_loss: 0.9429
# Epoch 6/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.6039 - loss: 0.8468 - val_accuracy: 0.6667 - val_loss: 0.9097
# Epoch 7/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.7155 - loss: 0.7884 - val_accuracy: 0.5833 - val_loss: 0.8854
# Epoch 8/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.6579 - loss: 0.7913 - val_accuracy: 0.5833 - val_loss: 0.8626
# Epoch 9/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.7126 - loss: 0.7565 - val_accuracy: 0.6250 - val_loss: 0.8284
# Epoch 10/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.7312 - loss: 0.7188 - val_accuracy: 0.6667 - val_loss: 0.8045
# Epoch 11/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.6539 - loss: 0.7729 - val_accuracy: 0.6667 - val_loss: 0.7882
# Epoch 12/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step - accuracy: 0.6955 - loss: 0.7209 - val_accuracy: 0.6667 - val_loss: 0.7745
# Epoch 13/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.7810 - loss: 0.6390 - val_accuracy: 0.6667 - val_loss: 0.7607
# Epoch 14/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.7665 - loss: 0.6583 - val_accuracy: 0.6875 - val_loss: 0.7483
# Epoch 15/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.7236 - loss: 0.6883 - val_accuracy: 0.6667 - val_loss: 0.7387
# Epoch 16/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.7957 - loss: 0.6015 - val_accuracy: 0.6667 - val_loss: 0.7289
# Epoch 17/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.7715 - loss: 0.6018 - val_accuracy: 0.6667 - val_loss: 0.7207
# Epoch 18/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.7329 - loss: 0.6279 - val_accuracy: 0.6458 - val_loss: 0.7172
# Epoch 19/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.7941 - loss: 0.5918 - val_accuracy: 0.6458 - val_loss: 0.7134
# Epoch 20/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.7957 - loss: 0.5544 - val_accuracy: 0.6667 - val_loss: 0.7065
# Epoch 21/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.7823 - loss: 0.5761 - val_accuracy: 0.6667 - val_loss: 0.7028
# Epoch 22/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.7438 - loss: 0.5954 - val_accuracy: 0.7083 - val_loss: 0.6974
# Epoch 23/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.8143 - loss: 0.5329 - val_accuracy: 0.6875 - val_loss: 0.6937
# Epoch 24/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.8139 - loss: 0.5212 - val_accuracy: 0.6667 - val_loss: 0.6923
# Epoch 25/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.8141 - loss: 0.5083 - val_accuracy: 0.6667 - val_loss: 0.6898

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(loss))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title("Loss Curves")
  plt.xlabel("Epochs")
  plt.legend()

  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title("Accuracy Curves")
  plt.xlabel("Epochs")
  plt.legend()

# %%
plot_loss_curves(history)

# %%
val_pred = model.predict(valid_data)
val_pred = val_pred.argmax(axis=1)
print(classification_report(val_pred, val_y))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.80        19
#            1       0.56      0.53      0.55        17
#            2       0.56      0.75      0.64        12
#
#     accuracy                           0.67        48
#    macro avg       0.67      0.67      0.66        48
# weighted avg       0.69      0.67      0.67        48

# %%
cfm_val = confusion_matrix(val_pred, val_y)
ax = sns.heatmap(cfm_val, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
print(classification_report(test_pred, test_y))
# Out:
# C:\Users\ajayk\anaconda3\envs\nus\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         6
#            1       0.75      0.60      0.67         5
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.58        12
#    macro avg       0.58      0.42      0.49        12
# weighted avg       0.81      0.58      0.68        12

# %%
cfm_test = confusion_matrix(test_pred, test_y)
ax = sns.heatmap(cfm_test, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
model.save('my_model.keras')

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ajayk\anaconda3\envs\nus\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
import numpy as np
  
from keras.models import load_model
  
model = load_model('my_model.keras')
image_path = r"C:\Users\ajayk\Desktop\skincancer\databse\Melanocyticnevus\ISIC_0000003.jpg"

image = image.load_img(image_path, target_size=(224, 224))
#plt.imshow(image)

img = np.array(image)
img = img / 255.0
img = img.reshape(1,224,224,3)
label = model.predict(img)
#print(label)
if label[0][0] > label[0][1]:
    print('Dermatofibroma')
elif label[0][1] > label[0][2]:
    print('Melanocyticnevus')
elif label[0][2] > label[0][3]:
    print('Melanoma')
else:
    print('Enter A vaild image')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001EEEADEB490> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Melanocyticnevus

# %%
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = load_model('my_model.keras')

# Load the image
image_path = r"C:\Users\ajayk\Desktop\skincancer\databse\Dermatofibroma\ISIC_0024386.jpg"
image = image.load_img(image_path, target_size=(224, 224))

# Preprocess the image
img = np.array(image)
img = img / 255.0
img = img.reshape(1, 224, 224, 3)

# Predict the label
label = model.predict(img)

# Determine the predicted class
class_names = ['Dermatofibroma', 'Melanocyticnevus', 'Melanoma']
predicted_class_index = np.argmax(label)
predicted_class = class_names[predicted_class_index]

# Print the predicted class
print("Predicted Class:", predicted_class)

# Display the image with the predicted label
plt.imshow(image)
plt.title(predicted_class)
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Predicted Class: Dermatofibroma

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Function to classify an image
def classify_image():
    # Load the trained model
    model = load_model('my_model.keras')
    
    # Open a dialog box to select an image file
    file_path = filedialog.askopenfilename()
    
    # Load the selected image
    image = Image.open(file_path)
    image = image.resize((224, 224))  # Resize the image to match model input size
    
    # Convert image to numpy array and preprocess
    img = np.array(image)
    img = img / 255.0
    img = img.reshape(1, 224, 224, 3)
    
    # Predict the label
    label = model.predict(img)
    
    # Determine the predicted class
    class_names = ['Dermatofibroma', 'Melanocyticnevus', 'Melanoma']
    predicted_class_index = np.argmax(label)
    predicted_class = class_names[predicted_class_index]
    
    # Display the image with the predicted label
    plt.imshow(image)
    plt.title(predicted_class)
    plt.axis('off')
    plt.show()

# Create a Tkinter window
root = tk.Tk()
root.title("Skin Cancer Classifier")

# Create a button to trigger image classification
classify_button = tk.Button(root, text="Classify Image", command=classify_image)
classify_button.pack(pady=10)

# Run the Tkinter event loop
root.mainloop()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000258F531A200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
